# %%
import matplotlib.pyplot as plt
import numpy as np
plt.xkcd()
plt.rcParams.update({'font.size': 20})
labels = ['Data Analytics\n (SQL)', 'Data Analytics\n (Python, R)', 'Machine Learning\n (Python)', 'Big Data\n (PySpark)', 'GIS\n(arcGIS)']
sizes = [25, 30, 20, 10, 15]
explode = (0, 0, 0, 0, 0)
plt.pie(sizes, explode = explode, labels = labels, colors = ['cadetblue', 'darkcyan', 'steelblue', 'cornflowerblue', 'lightsteelblue'])
# 'steelblue', royalblue, teal
circle = plt.Circle( (0,0), 0.65, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
# plt.rcParams.update({'font.size': 24})
# plt.title('MY INTERESTS AND SKILLS', fontweight = 'bold')
plt.tight_layout()
# plt.subplots_adjust(top=0.5)
# plt.annotate('My Interests\n & Skills', color = 'royalblue', fontweight = 'bold',  
#              xy=(-1.2, .0), xycoords='data',
#              xytext=(-4.6, 1.8), arrowprops=dict(arrowstyle="->", color = 'royalblue',
#                                                 connectionstyle="arc3", linewidth = 2))
plt.annotate('My Interests\n & Skills', color = 'royalblue', fontweight = 'bold', fontsize = 24,  
             xy=(-1.2, .0), xycoords='data',
             xytext=(-4.4, 0.4), arrowprops=dict(arrowstyle="->", color = 'royalblue',
                                                connectionstyle="arc3", linewidth = 2))
# plt.savefig('my_interests_and_skills.png', dpi=800, bbox_inches='tight')
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...
