# %%
import matplotlib.pyplot as plt
import numpy as np
plt.xkcd()
labels = ['Data Analytics (SQL)', 'Data Analytics (Python)', 'Machine Learning (Python)', 'Big Data (PySpark)', 'GIS (arcGIS)']
sizes = [25, 30, 20, 10, 15]
total = sum(data)
data_per = data/total*100
explode = (0, 0, 0, 0, 0)
plt.pie(sizes, explode = explode, labels = labels, colors = ['cadetblue', 'darkcyan', 'steelblue', 'cornflowerblue', 'lightsteelblue'])
# 'steelblue', royalblue, teal
circle = plt.Circle( (0,0), 0.65, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.title('MY INTERESTS AND SKILLS')
plt.tight_layout()
plt.savefig('my_interests_and_skills.jpg', dpi=200, bbox_inches='tight')
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...
